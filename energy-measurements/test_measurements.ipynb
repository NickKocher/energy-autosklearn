# %%
from autosklearn.pipeline.components import classification as c_spaces
from sklearn import ensemble as en
import configurations as cf
import algorithm_measurement as als
import sklearn.datasets
import sklearn.model_selection

# %%
cs = c_spaces.adaboost.AdaboostClassifier.get_hyperparameter_search_space()

# %%
config = cs.sample_configuration(1)

# %%
config.values()
# Out:
# ValuesView(Configuration(values={
#   'algorithm': 'SAMME.R',
#   'learning_rate': 0.021802232360641112,
#   'n_estimators': 467,
# })
# )

# %%
alg = en.AdaBoostClassifier(**config)
alg
# Out:
# AdaBoostClassifier(learning_rate=0.021802232360641112, n_estimators=467)

# %%
algorithm_dict = cf.create_algorithm_configurations()

# %%
algorithm_dict
# Out:
# {0: (sklearn.ensemble._weight_boosting.AdaBoostClassifier,
#   Configuration(values={
#     'algorithm': 'SAMME.R',
#     'learning_rate': 0.0891029327443437,
#     'n_estimators': 295,
#   })),
#  1: (sklearn.ensemble._weight_boosting.AdaBoostClassifier,
#   Configuration(values={
#     'algorithm': 'SAMME.R',
#     'learning_rate': 0.040435207251074586,
#     'n_estimators': 403,
#   })),
#  2: (sklearn.ensemble._weight_boosting.AdaBoostClassifier,
#   Configuration(values={
#     'algorithm': 'SAMME.R',
#     'learning_rate': 0.047753332923139775,
#     'n_estimators': 124,
#   })),
#  3: (sklearn.ensemble._weight_boosting.AdaBoostClassifier,
#   Configuration(values={
#     'algorithm': 'SAMME',
#     'learning_rate': 0.7957161587723142,
#     'n_estimators': 107,
#   })),
#  4: (sklearn.ensemble._weight_boosting.AdaBoostClassifier,
#   Configuration(values={
#     'algorithm': 'SAMME',
#     'learning_rate': 1.0266177830130365,
#     'n_estimators': 342,
#   })),
# ...

# %%
selected_confs = cf.select_algorithms(algorithm_dict)

# %%
print(selected_confs)
# Out:
# {0: (<class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>, Configuration(values={
#   'algorithm': 'SAMME.R',
#   'learning_rate': 0.0891029327443437,
#   'n_estimators': 295,
# })
# ), 1: (<class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>, Configuration(values={
#   'algorithm': 'SAMME.R',
#   'learning_rate': 0.040435207251074586,
#   'n_estimators': 403,
# })
# ), 2: (<class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>, Configuration(values={
#   'algorithm': 'SAMME.R',
#   'learning_rate': 0.047753332923139775,
#   'n_estimators': 124,
# })
# ), 3: (<class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>, Configuration(values={
#   'algorithm': 'SAMME',
#   'learning_rate': 0.7957161587723142,
#   'n_estimators': 107,
# })
# ), 4: (<class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>, Configuration(values={
#   'algorithm': 'SAMME',
#   'learning_rate': 1.0266177830130365,
#   'n_estimators': 342,
# })
# ...

# %%
data_X,data_y = sklearn.datasets.load_iris(return_X_y=True)

# %%
data_X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
sklearn.model_selection.train_test_split(data_X,data_y,train_size=0.3,test_size=0.7)
# Out:
# [array([[4.8, 3. , 1.4, 0.3],
#         [6.1, 2.6, 5.6, 1.4],
#         [6.4, 2.9, 4.3, 1.3],
#         [5.6, 3. , 4.5, 1.5],
#         [5.7, 3.8, 1.7, 0.3],
#         [6.6, 2.9, 4.6, 1.3],
#         [7.2, 3.6, 6.1, 2.5],
#         [4.8, 3.1, 1.6, 0.2],
#         [4.6, 3.4, 1.4, 0.3],
#         [6.3, 3.3, 6. , 2.5],
#         [6.4, 2.8, 5.6, 2.2],
#         [4.4, 3.2, 1.3, 0.2],
#         [6.3, 2.5, 4.9, 1.5],
#         [6.9, 3.2, 5.7, 2.3],
#         [5.6, 2.7, 4.2, 1.3],
#         [6.3, 2.3, 4.4, 1.3],
#         [6. , 2.2, 4. , 1. ],
#         [5. , 3.5, 1.6, 0.6],
#         [6.6, 3. , 4.4, 1.4],
#         [5.2, 2.7, 3.9, 1.4],
#         [5.2, 3.5, 1.5, 0.2],
#         [5.7, 4.4, 1.5, 0.4],
#         [7.9, 3.8, 6.4, 2. ],
#         [6.3, 2.9, 5.6, 1.8],
#         [6.8, 3. , 5.5, 2.1],
#         [5.8, 2.7, 5.1, 1.9],
#         [6.7, 3.1, 4.4, 1.4],
#         [5.1, 3.5, 1.4, 0.2],
#         [5.7, 2.9, 4.2, 1.3],
#         [7.2, 3.2, 6. , 1.8],
#         [5.8, 2.7, 3.9, 1.2],
# ...

# %%
alg.fit(data_X,data_y)
alg.score(data_X,data_y)
# Out:
# 0.9266666666666666

# %%
alg.algorithm
# Out:
# 'SAMME.R'

# %%
import numpy as np

# %%
arr = np.load("/home/kocher/energy-autosklearn/metadata-retraining/run_2/1711718887708571285_1529",allow_pickle=True)
print(arr)
# Out:
# [1711805177442564595 11092729532
# ...

# %%
ONEMILLION = 1000000
print(f"{arr[1]//ONEMILLION }")
# Out:
# 11092
